# %%
import seaborn as sns
import pandas as pd
from pyproj import Proj, transform

# %%
df = pd.read_csv("puzzle.csv", names = ["X", "Y"])

# %%
df.head(10)
# Out:
#           X         Y
# 0  0.397150  2.113629
# 1  0.397150  2.113629
# 2  0.397150  2.113629
# 3  0.397150  2.113629
# 4  0.397150  2.113629
# 5  0.397150  2.113629
# 6  0.397150  2.113629
# 7  0.397150  2.113629
# 8  0.967562 -0.099246
# 9  0.061841 -1.333110

# %%
#Plot scatterplot -> See it's the shape of a world map! 
sns.scatterplot(data = df, x = df.Y, y = df.X)
# Out:
# <AxesSubplot:xlabel='Y', ylabel='X'>

# %%
#Write to new csv file 
df.to_csv("Coordinates.csv")

# %%
# Out:
# Connection not successful, please try again
